# %%
import numpy as np
A=np.array([[10,13,14],[16,17,12],[-12,10,19]])
print(A,type(A))
# Out:
# [[ 10  13  14]
#  [ 16  17  12]
#  [-12  10  19]] <class 'numpy.ndarray'>

# %%
X=A[A<0] 
X
# Out:
# array([-12])

# %%
X1=A[A%2==0]
X1
# Out:
# array([ 10,  14,  16,  12, -12,  10])
